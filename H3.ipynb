# %%
import pandas as pd

# %%
data = pd.read_csv('/content/earthquakes.csv')

# %%
data
# Out:
#      alert  ...                                                url
# 0      NaN  ...  https://earthquake.usgs.gov/earthquakes/eventp...
# 1      NaN  ...  https://earthquake.usgs.gov/earthquakes/eventp...
# 2      NaN  ...  https://earthquake.usgs.gov/earthquakes/eventp...
# 3      NaN  ...  https://earthquake.usgs.gov/earthquakes/eventp...
# 4      NaN  ...  https://earthquake.usgs.gov/earthquakes/eventp...
# ...    ...  ...                                                ...
# 9327   NaN  ...  https://earthquake.usgs.gov/earthquakes/eventp...
# 9328   NaN  ...  https://earthquake.usgs.gov/earthquakes/eventp...
# 9329   NaN  ...  https://earthquake.usgs.gov/earthquakes/eventp...
# 9330   NaN  ...  https://earthquake.usgs.gov/earthquakes/eventp...
# 9331   NaN  ...  https://earthquake.usgs.gov/earthquakes/eventp...
#
# [9332 rows x 26 columns]

# %%
#Exercise 1
ex1 = sum((data.magType.str.contains('ml')) & (data.type.str.contains('explosion')))
ex1
# Out:
# 79

# %%
#Exercise 2
ex2 = data.mag[(data.place.str.contains('Alaska'))&~(data.place.str.contains('\d{3,}'))].mean()
print(ex2)
# Out:
# 1.3744199088678577

# %%
#Exercise 3
data.time = pd.to_datetime(data.time)
data['time'].unique
ex31 = data.mag[(pd.DatetimeIndex(data['time']).month>=1)&(pd.DatetimeIndex(data['time']).month<=3)].mean()
ex32 = data.mag[(pd.DatetimeIndex(data['time']).month>=4)&(pd.DatetimeIndex(data['time']).month<=6)].mean()
ex33 = data.mag[(pd.DatetimeIndex(data['time']).month>=7)&(pd.DatetimeIndex(data['time']).month<=9)].mean()
ex34 = data.mag[(pd.DatetimeIndex(data['time']).month>=10)&(pd.DatetimeIndex(data['time']).month<=12)].mean()
print(ex31)
print(ex32)
print(ex33)
print(ex34)
# Out:
# nan
# nan
# 1.466735124760082
# 1.5360446493569568
